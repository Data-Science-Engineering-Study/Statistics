# %% [markdown]
# # 부록

# %% [markdown]
# ## 1. matplotlib color list

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# ![image.png](attachment:d26105e1-7f25-4326-9e63-b45c9a064a9b.png)
